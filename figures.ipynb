# %%
import plot_galaxy as gplot
import mg
import os
import time
import matplotlib.pyplot as plt
# %matplotlib inline
import galaxy_tools
# Out:
# Missing firefly, obtain it at http://github.com/ageller/Firefly or pip install firefly.

# %%
csv_files = ['3D shapes/FIREm12b_res7100_600_AGE.csv']
gplot.ca_a_scatter(csv_files, title = 'm12b (z=0) c/a vs. a of Stellar Age Population Shapes')

csv_files = ['3D shapes/FIREm12c_res7100_600_AGE.csv']
gplot.ca_a_scatter(csv_files, title = 'm12c (z=0) c/a vs. a of Stellar Age Population Shapes')

csv_files = ['3D shapes/FIREm12f_res7100_600_AGE.csv']
gplot.ca_a_scatter(csv_files, title = 'm12f (z=0) c/a vs. a of Stellar Age Population Shapes')

csv_files = ['3D shapes/FIRE_m12_elvis_RomeoJuliet_res3500_AGE.csv']
gplot.ca_a_scatter(csv_files, title = 'Romeo (z=0) c/a vs. a of Stellar Age Population Shapes')

# %%
csv_files1 = ['m12 redshift shapes/FIRE_m12b.csv']
csv_files2 = ['m12 redshift shapes/FIRE_m12b_05.csv']
csv_files3 = ['3D shapes/FIREm12b_res7100_600_AGE.csv']
gplot.baca_combine(csv_files1, csv_files2, csv_files3, title1 = 'm12b Shape Evolution', title2 = 'm12b Shape Evolution (Stellar Age < 0.5Gyr)', title3 = 'm12b Stellar Ages (z=0)')

csv_files1 = ['m12 redshift shapes/FIRE_m12c.csv']
csv_files2 = ['m12 redshift shapes/FIRE_m12c_05.csv']
csv_files3 = ['3D shapes/FIREm12c_res7100_600_AGE.csv']
gplot.baca_combine(csv_files1, csv_files2, csv_files3, title1 = 'm12c Shape Evolution', title2 = 'm12c Shape Evolution (Stellar Age < 0.5Gyr)', title3 = 'm12c Stellar Ages (z=0)')

csv_files1 = ['m12 redshift shapes/FIRE_m12f.csv']
csv_files2 = ['m12 redshift shapes/FIRE_m12f_05.csv']
csv_files3 = ['3D shapes/FIREm12f_res7100_600_AGE.csv']
gplot.baca_combine(csv_files1, csv_files2, csv_files3, title1 = 'm12f Shape Evolution', title2 = 'm12f Shape Evolution (Stellar Age < 0.5Gyr)', title3 = 'm12f Stellar Ages (z=0)')

csv_files1 = ['m12 redshift shapes/FIRE_m12_romeo.csv']
csv_files2 = ['m12 redshift shapes/FIRE_m12_romeo_05.csv']
csv_files3 = ['3D shapes/FIRE_m12_elvis_RomeoJuliet_res3500_AGE.csv']
gplot.baca_combine(csv_files1, csv_files2, csv_files3, title1 = 'Romeo Shape Evolution', title2 = 'Romeo Shape Evolution (Stellar Age < 0.5Gyr)', title3 = 'Romeo Stellar Ages (z=0)')

# %%
csv_files1 = ['m12 redshift shapes/FIRE_m12b.csv']
csv_files2 = ['m12 redshift shapes/FIRE_m12b_01.csv']
csv_files3 = ['3D shapes/FIREm12b_res7100_600_AGE.csv']
gplot.baca_combine(csv_files1, csv_files2, csv_files3, title1 = 'm12b Shape Evolution', title2 = 'm12b Shape Evolution (Stellar Age < 0.1Gyr)', title3 = 'm12b Stellar Ages (z=0)')

csv_files1 = ['m12 redshift shapes/FIRE_m12c.csv']
csv_files2 = ['m12 redshift shapes/FIRE_m12c_01.csv']
csv_files3 = ['3D shapes/FIREm12c_res7100_600_AGE.csv']
gplot.baca_combine(csv_files1, csv_files2, csv_files3, title1 = 'm12c Shape Evolution', title2 = 'm12c Shape Evolution (Stellar Age < 0.1Gyr)', title3 = 'm12c Stellar Ages (z=0)')


csv_files1 = ['m12 redshift shapes/FIRE_m12f.csv']
csv_files2 = ['m12 redshift shapes/FIRE_m12f_01.csv']
csv_files3 = ['3D shapes/FIREm12f_res7100_600_AGE.csv']
gplot.baca_combine(csv_files1, csv_files2, csv_files3, title1 = 'm12f Shape Evolution', title2 = 'm12f Shape Evolution (Stellar Age < 0.1Gyr)', title3 = 'm12f Stellar Ages (z=0)')

csv_files1 = ['m12 redshift shapes/FIRE_m12_romeo.csv']
csv_files2 = ['m12 redshift shapes/FIRE_m12_romeo_01.csv']
csv_files3 = ['3D shapes/FIRE_m12_elvis_RomeoJuliet_res3500_AGE.csv']
gplot.baca_combine(csv_files1, csv_files2, csv_files3, title1 = 'Romeo Shape Evolution', title2 = 'Romeo Shape Evolution (Stellar Age < 0.1Gyr)', title3 = 'Romeo Stellar Ages (z=0)')

# %%
csv_files1 = ['m12 redshift shapes/FIRE_m12_juliet.csv']
csv_files2 = ['m12 redshift shapes/FIRE_juliet_01.csv']
csv_files3 = ['3D shapes/FIRE_m12_elvis_RomeoJuliet_res3500_AGE.csv']
gplot.baca_combine(csv_files1, csv_files2, csv_files3, title1 = 'Juliet Shape Evolution', title2 = 'Juliet Shape Evolution (Stellar Age <= 10e8)', title3 = 'Juliet Stellar Ages (z=0)')

# %%
csv_files1 = ['m12 redshift shapes/FIRE_m12b.csv']
csv_files2 = ['m12 redshift shapes/FIRE_m12b_01.csv']
csv_files3 = ['3D shapes/FIRE_m12b_res7100_AGE.csv']
gplot.baca_combine(csv_files1, csv_files2, csv_files3, title1 = 'm12b Shape Evolution', title2 = 'm12b Shape Evolution (Stellar Age <= 10e8)', title3 = 'm12b Stellar Ages (z=0)')

# %%
csv_files = [
    'outlier shapes/object_143_1.csv'
]

#gplot.baca_age(csv_files)
# gplot.baca_redshift(csv_files, title = 'm12c Shape Evolution')
gplot.baca4(csv_files)

# %%
csv_files = [
    'm12 redshift shapes/FIRE_m12b_01.csv'
]

gplot.baca_lookback(csv_files, title = 'm12b Shape Evolution (Stellar Age <= 10e8)')

# %%
csv_files = [
    'm12 redshift shapes/FIRE_m12_juliet.csv'
]

gplot.baca_lookback(csv_files, title = 'Juliet Shape Evolution')

# %%
csv_files = [
    'm12 redshift shapes/FIRE_m12_romeo.csv'
]

#gplot.baca_age(csv_files)
# gplot.baca_redshift(csv_files, title = 'm12c Shape Evolution')
gplot.baca_lookback(csv_files, title = 'Romeo Shape Evolution')

# %%
csv_files = [
    'm12 redshift shapes/FIRE_m12b.csv'
]

#gplot.baca_age(csv_files)
# gplot.baca_redshift(csv_files, title = 'm12b Shape Evolution')
gplot.baca_lookback(csv_files, title = 'm12b Shape Evolution')

# %%
csv_files = [
    'm12 redshift shapes/FIRE_m12c.csv'
]

#gplot.baca_age(csv_files)
# gplot.baca_redshift(csv_files, title = 'm12c Shape Evolution')
gplot.baca_lookback(csv_files, title = 'm12c Shape Evolution')

# %%
csv_files = [
    'm12 redshift shapes/FIRE_m12f.csv'
]

#gplot.baca_age(csv_files)
# gplot.baca_redshift(csv_files, title = 'm12c Shape Evolution')
gplot.baca_lookback(csv_files, title = 'm12f Shape Evolution')

# %%
csv_files = [
    'm12 redshift shapes/FIRE_m12m.csv'
]

#gplot.baca_age(csv_files)
# gplot.baca_redshift(csv_files, title = 'm12c Shape Evolution')
gplot.baca_lookback(csv_files, title = 'm12m Shape Evolution')

# %%
csv_files = [
    'm12 redshift shapes/FIRE_m12r.csv'
]

#gplot.baca_age(csv_files)
# gplot.baca_redshift(csv_files, title = 'm12c Shape Evolution')
gplot.baca_lookback(csv_files, title = 'm12r Shape Evolution')

# %%
csv_files = [
    'm12 redshift shapes/FIRE_m12w.csv'
]

#gplot.baca_age(csv_files)
# gplot.baca_redshift(csv_files, title = 'm12c Shape Evolution')
gplot.baca_lookback(csv_files, title = 'm12w Shape Evolution')

# %%
csv_files = [
    'm12 redshift shapes/FIRE_m12z.csv'
]

#gplot.baca_age(csv_files)
# gplot.baca_redshift(csv_files, title = 'm12c Shape Evolution')
gplot.baca_lookback(csv_files, title = 'm12z Shape Evolution')

# %%
csv_files = [
    'm12 redshift shapes/FIRE_m12b_elvis_RomeoJuliet_2.csv'
]

#gplot.baca_age(csv_files)
gplot.baca_redshift(csv_files, title = 'm12_elvis_Juliet Shape Evolution')

# %%
csv_files = [
    'm12 redshift shapes/FIRE_m12bm_res7100.csv'
]

#gplot.baca_age(csv_files)
gplot.baca_redshift(csv_files, title = 'FIRE_m12m_res7100 Shape Evolution')

# %%
csv_files = [
    '3D shapes/FIREm11h_res7100_600_AGE.csv',
]

gplot.baca_age(csv_files, title = 'm11h_res7100 Shape by Stellar Age (z = 0)')

# %%
csv_files = [
    '3D shapes/FIREm11v_res7100_600_AGE.csv',
]

gplot.baca_age(csv_files, title = 'm11v_res7100 Shape by Stellar Age (z = 0)')

# %%
csv_files = [
    '3D shapes/FIRE_m12bc_res7100_AGE.csv',
]

gplot.baca_age(csv_files, title = 'm12c_res7100 Shape by Stellar Age (z = 0)')

# %%
csv_files = [
    '3D shapes/FIREm11c_res2100_600_AGE.csv',
]

gplot.baca_age(csv_files, title = 'm11c_res2100 Shape by Stellar Age (z = 0)')

# %%
csv_files = [
    '3D shapes/FIRE_m12b_elvis_RomeoJuliet_res3500_AGE.csv',
]

gplot.baca_age(csv_files, title = 'm12_elvis_Romeo Shape by Stellar Age (z = 0)')

# %%
csv_files = [
    '3D shapes/FIREBox_host_m7.csv',
    '3D shapes/FIREBox_host_m8.csv',
    '3D shapes/FIREBox_host_m9.csv',
    '3D shapes/FIREBox_host_m10.csv',
    '3D shapes/FIREBox_host_m11.csv',

    '3D shapes/FIREBox_satellite_m7.csv',
    '3D shapes/FIREBox_satellite_m8.csv',
    '3D shapes/FIREBox_satellite_m9.csv',
    '3D shapes/FIREBox_satellite_m10.csv',
    '3D shapes/FIREBox_satellite_m11.csv',

    '3D shapes/FIREm10.csv',
    '3D shapes/FIREm11.csv',
    '3D shapes/FIREBox_outliers.csv',

    '3D shapes/FIRE_m12b_1.csv',
    '3D shapes/FIRE_m12b_2.csv',
    '3D shapes/FIRE_m12b_3.csv',
    '3D shapes/FIRE_m12b_4.csv',
]

gplot.baca2(csv_files)

# %%
csv_files = [
    '3D shapes/FIREBox_satellite_m7.csv',
    '3D shapes/FIREBox_satellite_m8.csv',
    '3D shapes/FIREBox_satellite_m9.csv',
    '3D shapes/FIREBox_satellite_m10.csv',
    '3D shapes/FIREBox_satellite_m11.csv'
]

gplot.baca2(csv_files)

# %%
csv_files = [
    '3D shapes/FIREBox_host_m7.csv',
    '3D shapes/FIREBox_host_m8.csv',
    '3D shapes/FIREBox_host_m9.csv',
    '3D shapes/FIREBox_host_m10.csv',
    '3D shapes/FIREBox_host_m11.csv'
]

gplot.baca2(csv_files)

# %%
csv_files = [
    '3D shapes/FIREBoxm7.csv',
    '3D shapes/FIREBoxm8.csv',
    '3D shapes/FIREBoxm9.csv',
    '3D shapes/FIREBoxm10.csv',
    '3D shapes/FIREm10.csv',
    '3D shapes/FIREm11.csv',
]
gplot.baloga_3d(csv_files)
for i in csv_files:
    gplot.baloga_3d([i])

# %%
csv_files = [
    '2D shapes/object_398.csv'
]
gplot.baloga_2d(csv_files)
