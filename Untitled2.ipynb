# %%
import plot_galaxy as gplot
import matplotlib.pyplot as plt
# %matplotlib inline
folder_path = 'm12 redshift shapes/m12b_02'  # Replace with your folder path
gplot.plot_evolution_scatter(folder_path, show_labels=False)  # Labels turned off
