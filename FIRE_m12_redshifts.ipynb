# %%
import plot_galaxy as gplot
import mg
import galaxy_tools
# These snapshots correspond to redshifts of 7, 5, 3, 2, 1, 0.5, 0.1, and 0, respectively. 
snap_nums = ['041', '067', 120, 172, 277, 382, 534, 600]
snap_nums = ['020', '029', '059', '088', 102, 214, 294, 332, 412, 446, 486, 590]
# Out:
# Missing firefly, obtain it at http://github.com/ageller/Firefly or pip install firefly.

# %%
# snap_nums = [600]
snap_nums = ['067', 277, 534, 600]
sim_inputs = [
    'm12b_res7100',
]
for snap_num in snap_nums:
    mg.measure_m12(sim_inputs, snap_num = snap_num, age_range = 0.1)
# Out:
# loading galaxy 'm12b_res7100'
# measured galaxy m12b_res7100
# Time taken for loading: 53.48 seconds
# Time taken for masking: 9.49 seconds
# Total time taken for galaxy 'm12b_res7100': 63.26 seconds
# loading galaxy 'm12b_res7100'
# measured galaxy m12b_res7100
# Time taken for loading: 227.22 seconds
# Time taken for masking: 9.06 seconds
# Total time taken for galaxy 'm12b_res7100': 240.72 seconds
# loading galaxy 'm12b_res7100'
# measured galaxy m12b_res7100
# Time taken for loading: 413.84 seconds
# Time taken for masking: 8.42 seconds
# Total time taken for galaxy 'm12b_res7100': 425.85 seconds
# loading galaxy 'm12b_res7100'
# measured galaxy m12b_res7100
# Time taken for loading: 440.17 seconds
# Time taken for masking: 8.44 seconds
# Total time taken for galaxy 'm12b_res7100': 451.16 seconds

# %%
# snap_nums = [600]
sim_inputs = [
    #'m12b_res7100',
    'm12c_res7100',
    'm12f_res7100',
]
for snap_num in snap_nums:
    mg.measure_m12(sim_inputs, snap_num = snap_num)
# Out:
# loading galaxy 'm12c_res7100'
# Galaxy too small: only has 55 star particles
# measured galaxy m12c_res7100
# Time taken for loading: 128.83 seconds
# Time taken for masking: 17.52 seconds
# Total time taken for galaxy 'm12c_res7100': 146.37 seconds
# loading galaxy 'm12f_res7100'
# Galaxy too small: only has 29 star particles
# measured galaxy m12f_res7100
# Time taken for loading: 66.19 seconds
# Time taken for masking: 10.76 seconds
# Total time taken for galaxy 'm12f_res7100': 76.97 seconds
# loading galaxy 'm12c_res7100'
# Galaxy too small: only has 174 star particles
# measured galaxy m12c_res7100
# Time taken for loading: 121.13 seconds
# Time taken for masking: 17.86 seconds
# Total time taken for galaxy 'm12c_res7100': 139.11 seconds
# loading galaxy 'm12f_res7100'
# Galaxy too small: only has 66 star particles
# measured galaxy m12f_res7100
# Time taken for loading: 66.06 seconds
# Time taken for masking: 11.37 seconds
# ...

# %%
# snap_nums = ['041', '067', 120, 172, 277, 382, 534, 600]
sim_inputs = [
    # 'm12i_res7100',
    'm12m_res7100',
    'm12r_res7100',
    'm12w_res7100',
    'm12z_res4200',
]
for snap_num in snap_nums:
    mg.measure_m12(sim_inputs, snap_num = snap_num)
# Out:
# loading galaxy 'm12m_res7100'
# Galaxy too small: only has 306 star particles
# measured galaxy m12m_res7100
# Time taken for loading: 116.90 seconds
# Time taken for masking: 19.11 seconds
# Total time taken for galaxy 'm12m_res7100': 136.04 seconds
# loading galaxy 'm12r_res7100'
# Galaxy too small: only has 28 star particles
# measured galaxy m12r_res7100
# Time taken for loading: 39.81 seconds
# Time taken for masking: 7.45 seconds
# Total time taken for galaxy 'm12r_res7100': 47.29 seconds
# loading galaxy 'm12w_res7100'
# Galaxy too small: only has 20 star particles
# measured galaxy m12w_res7100
# Time taken for loading: 47.40 seconds
# Time taken for masking: 9.72 seconds
# Total time taken for galaxy 'm12w_res7100': 57.16 seconds
# loading galaxy 'm12z_res4200'
# Galaxy too small: only has 176 star particles
# measured galaxy m12z_res4200
# Time taken for loading: 83.37 seconds
# Time taken for masking: 17.16 seconds
# ...

# %%
# snap_nums = ['041', '067', 120, 172, 277, 382, 534, 600]
snap_nums = ['020', '029', '059', '088', 102, 214, 294, 332, 412, 446, 486, 590]
sim_inputs = [
    'm12_elvis_RomeoJuliet_res3500',
]
for snap_num in snap_nums:
    mg.measure_m12(sim_inputs, snap_num = snap_num)
# Out:
# loading galaxy 'm12_elvis_RomeoJuliet_res3500'
# measured galaxy m12_elvis_RomeoJuliet_res3500
# Time taken for loading: 232.15 seconds
# Time taken for masking: 36.05 seconds
# Total time taken for galaxy 'm12_elvis_RomeoJuliet_res3500': 268.27 seconds
# loading galaxy 'm12_elvis_RomeoJuliet_res3500'
# measured galaxy m12_elvis_RomeoJuliet_res3500
# Time taken for loading: 245.68 seconds
# Time taken for masking: 37.05 seconds
# Total time taken for galaxy 'm12_elvis_RomeoJuliet_res3500': 282.94 seconds
# loading galaxy 'm12_elvis_RomeoJuliet_res3500'
# measured galaxy m12_elvis_RomeoJuliet_res3500
# Time taken for loading: 276.58 seconds
# Time taken for masking: 40.55 seconds
# Total time taken for galaxy 'm12_elvis_RomeoJuliet_res3500': 319.26 seconds
# loading galaxy 'm12_elvis_RomeoJuliet_res3500'
# measured galaxy m12_elvis_RomeoJuliet_res3500
# Time taken for loading: 324.86 seconds
# Time taken for masking: 39.28 seconds
# ...

# %%
# snap_nums = ['041', '067', 120, 172, 277, 382, 534, 600]
snap_nums = [590]
sim_inputs = [
    'm12_elvis_RomeoJuliet_res3500',
]
for snap_num in snap_nums:
    mg.measure_m12(sim_inputs, snap_num = snap_num, host = 2)
# Out:
# loading galaxy 'm12_elvis_RomeoJuliet_res3500'
# Big galaxy: has 14654800 star particles, will take a long time
# measured galaxy m12_elvis_RomeoJuliet_res3500
# Time taken for loading: 1441.34 seconds
# Time taken for masking: 52.87 seconds
# Total time taken for galaxy 'm12_elvis_RomeoJuliet_res3500': 1767.49 seconds

# %%
# now, things get funny. Romulus_Remus doesn't have snapshots 041 and 277. 
# we replace those with 046 (z = 6.51219511) and 250 (z = 1.18750000). 
# snap_nums = ['046', '067', 120, 172, 277, 382, 534, 600] 020', '032', '052', '085', 
snap_nums = [100, 200, 280, 320, 360, 400, 440, 480, 560]
sim_inputs = [
    'm12_elvis_RomulusRemus_res4000'
]
for snap_num in snap_nums:
    mg.measure_m12(sim_inputs, snap_num = snap_num)
# Out:
# loading galaxy 'm12_elvis_RomulusRemus_res4000'
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 9
#       5 sim_inputs = [
#       6     'm12_elvis_RomulusRemus_res4000'
#       7 ]
#       8 for snap_num in snap_nums:
# ----> 9     mg.measure_m12(sim_inputs, snap_num = snap_num)
#
# File /nfspool-0/home/lyxia/scripts/FIRE Geometry/mg.py:1343, in measure_m12(sim_inputs, snap_num, host)
#    1340 sim_path = '/DFS-L/DATA/cosmo/grenache/omyrtaj/FIRE/' + str(sim) + '/output/snapdir_' + str(snap_num) + '/'
#    1342 load_start_time = time.time()
# -> 1343 halo = galaxy_tools.load_halo(halo_path, snap_num, host=True, filetype='hdf5', hostnumber=host)
#    1344 star_snapdict, gas_snapdict = galaxy_tools.load_sim(sim_path, snap_num)
#    1345 load_end_time = time.time()
#
# ...

# %%
sim_inputs = [
    'm12_elvis_RomulusRemus_res4000'
]
for snap_num in snap_nums:
    mg.measure_m12(sim_inputs, snap_num = snap_num, host = 2)

# %%
# 'm12i_res7100' doesn't have the host center calculated the usual way
# they are located here: /DFS-L/DATA/cosmo/grenache/omyrtaj/analysis_data/m12i_res7100
