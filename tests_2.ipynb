# %%
import pandas as pd
import matplotlib.pyplot as plt
import plot_galaxy as gplot


gplot.radius_check('m12_redshift_shapes/FIRE_m12b_01.csv', 'm12b Max Radius as a function of Lookback Time')
gplot.radius_check('m12_redshift_shapes/FIRE_m12c_01.csv', 'm12c Max Radius as a function of Lookback Time')
gplot.radius_check('m12_redshift_shapes/FIRE_m12f_01.csv', 'm12f Max Radius as a function of Lookback Time')
gplot.radius_check('m12_redshift_shapes/FIRE_romeo_01.csv','Romeo Max Radius as a function of Lookback Time')
