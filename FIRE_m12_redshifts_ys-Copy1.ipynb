# %%
import plot_galaxy as gplot
import mg
import galaxy_tools
import time
# These snapshots correspond to redshifts of 7, 5, 3, 2, 1, 0.5, 0.1, and 0, respectively. 
age = 0.5
snap_nums = ['020', '029', '059', '088', 102, 214, 294, 332, 412, 446, 486, 590, '041', '067', 120, 172, 277, 382, 534, 600]
snap_nums = ['020', '029', '041', '059', '067', '088', 102, 120, 172, 214, 277, 294, 332, 382, 412, 446, 486, 534, 590, 600]
# Out:
# Missing firefly, obtain it at http://github.com/ageller/Firefly or pip install firefly.

# %%
start_time = time.time()
sim_inputs = [
    'm12b_res7100',
]
for snap_num in snap_nums:
    star_center = mg.measure_m12(sim_inputs, snap_num = snap_num, age_range = age)
    k = len(star_center['Coordinates'])
    if k >= 5000:
        csv_file = 'm12 redshift shapes/m12b_02/m12b_coords_' + str(snap_num) + '.csv'
        mg.save_coordinates(star_center, csv_file)
    else:
        print('Only' + str(k) + ' star particles in  ' + str(snap_num) + '.')
        csv_file = 'm12 redshift shapes/m12b_02/m12b_coords_INS' + str(snap_num) + '.csv'
        mg.save_coordinates(star_center, csv_file)
end_time = time.time() 
elapsed_time = end_time - start_time
print(f"Total time taken: {elapsed_time:.2f} seconds")
# Out:
# Galaxy too small: only has 135 star particles
# measured galaxy m12b_res7100
# Measured galaxy 'm12b_res7100' at snapshot '020' in 75.54 seconds
# Only135 star particles in  020.
# Coordinates saved to m12 redshift shapes/m12b_02/m12b_coords_INS020.csv
# Galaxy too small: only has 172 star particles
# measured galaxy m12b_res7100
# Measured galaxy 'm12b_res7100' at snapshot '029' in 88.68 seconds
# Only172 star particles in  029.
# Coordinates saved to m12 redshift shapes/m12b_02/m12b_coords_INS029.csv
# measured galaxy m12b_res7100
# Measured galaxy 'm12b_res7100' at snapshot '041' in 75.04 seconds
# Only1295 star particles in  041.
# Coordinates saved to m12 redshift shapes/m12b_02/m12b_coords_INS041.csv
# measured galaxy m12b_res7100
# Measured galaxy 'm12b_res7100' at snapshot '059' in 77.20 seconds
# Only2010 star particles in  059.
# Coordinates saved to m12 redshift shapes/m12b_02/m12b_coords_INS059.csv
# measured galaxy m12b_res7100
# ...

# %%
start_time = time.time()
sim_inputs = [
    'm12c_res7100',
]
for snap_num in snap_nums:
    star_center = mg.measure_m12(sim_inputs, snap_num = snap_num, age_range = age)
    k = len(star_center['Coordinates'])
    if k >= 5000:
        csv_file = 'm12 redshift shapes/m12c_02/m12c_coords_' + str(snap_num) + '.csv'
        mg.save_coordinates(star_center, csv_file)
    else:
        print('Only ' + str(k) + ' star particles in snapshot ' + str(snap_num) + '.')
        csv_file = 'm12 redshift shapes/m12c_02/m12c_coords_INS' + str(snap_num) + '.csv'
        mg.save_coordinates(star_center, csv_file)
end_time = time.time() 
elapsed_time = end_time - start_time
print(f"Total time taken: {elapsed_time:.2f} seconds")
# Out:
# Galaxy too small: only has 55 star particles
# measured galaxy m12c_res7100
# Measured galaxy 'm12c_res7100' at snapshot '020' in 147.09 seconds
# Only 55 star particles in snapshot 020.
# Coordinates saved to m12 redshift shapes/m12c_02/m12c_coords_INS020.csv
# Galaxy too small: only has 174 star particles
# measured galaxy m12c_res7100
# Measured galaxy 'm12c_res7100' at snapshot '029' in 148.02 seconds
# Only 174 star particles in snapshot 029.
# Coordinates saved to m12 redshift shapes/m12c_02/m12c_coords_INS029.csv
# measured galaxy m12c_res7100
# Measured galaxy 'm12c_res7100' at snapshot '041' in 136.05 seconds
# Only 2898 star particles in snapshot 041.
# Coordinates saved to m12 redshift shapes/m12c_02/m12c_coords_INS041.csv
# measured galaxy m12c_res7100
# Measured galaxy 'm12c_res7100' at snapshot '059' in 179.91 seconds
# Coordinates saved to m12 redshift shapes/m12c_02/m12c_coords_059.csv
# measured galaxy m12c_res7100
# ...

# %%
start_time = time.time()
snap_nums = [534, 590, 600]
sim_inputs = [
    'm12f_res7100',
]
for snap_num in snap_nums:
    star_center = mg.measure_m12(sim_inputs, snap_num = snap_num, age_range = age)
    k = len(star_center['Coordinates'])
    if k >= 5000:
        csv_file = 'm12 redshift shapes/m12f_02/m12f_coords_' + str(snap_num) + '.csv'
        mg.save_coordinates(star_center, csv_file)
    else:
        print('Only ' + str(k) + ' star particles in snapshot ' + str(snap_num) + '.')
        csv_file = 'm12 redshift shapes/m12f_02/m12f_coords_INS' + str(snap_num) + '.csv'
        mg.save_coordinates(star_center, csv_file)
end_time = time.time() 
elapsed_time = end_time - start_time
print(f"Total time taken: {elapsed_time:.2f} seconds")
# Out:
# measured galaxy m12f_res7100
# Measured galaxy 'm12f_res7100' at snapshot '534' in 406.03 seconds
# Coordinates saved to m12 redshift shapes/m12f_02/m12f_coords_534.csv
# measured galaxy m12f_res7100
# Measured galaxy 'm12f_res7100' at snapshot '590' in 451.19 seconds
# Coordinates saved to m12 redshift shapes/m12f_02/m12f_coords_590.csv
# measured galaxy m12f_res7100
# Measured galaxy 'm12f_res7100' at snapshot '600' in 455.96 seconds
# Coordinates saved to m12 redshift shapes/m12f_02/m12f_coords_600.csv
# Total time taken: 1322.80 seconds

# %%
snap_nums = ['020', '029', '041', '059', '067', '088', 102, 120, 172, 214, 277, 294, 332, 382, 412, 446, 486, 534, 590, 600]
start_time = time.time()
sim_inputs = [
    'm12_elvis_RomeoJuliet_res3500'
]
for snap_num in snap_nums:
    star_center = mg.measure_m12(sim_inputs, snap_num = snap_num, age_range = age)
    k = len(star_center['Coordinates'])
    if k >= 5000:
        csv_file = 'm12 redshift shapes/romeo_02/romeo_coords_' + str(snap_num) + '.csv'
        mg.save_coordinates(star_center, csv_file)
    else:
        print('Only ' + str(k) + ' star particles in snapshot ' + str(snap_num) + '.')
        csv_file = 'm12 redshift shapes/romeo_02/romeo_coords_INS' + str(snap_num) + '.csv'
        mg.save_coordinates(star_center, csv_file)
end_time = time.time() 
elapsed_time = end_time - start_time
print(f"Total time taken: {elapsed_time:.2f} seconds")
# Out:
# measured galaxy m12_elvis_RomeoJuliet_res3500
# Measured galaxy 'm12_elvis_RomeoJuliet_res3500' at snapshot '020' in 285.90 seconds
# Only 1273 star particles in snapshot 020.
# Coordinates saved to m12 redshift shapes/romeo_02/romeo_coords_INS020.csv
# measured galaxy m12_elvis_RomeoJuliet_res3500
# Measured galaxy 'm12_elvis_RomeoJuliet_res3500' at snapshot '029' in 280.41 seconds
# Coordinates saved to m12 redshift shapes/romeo_02/romeo_coords_029.csv
# measured galaxy m12_elvis_RomeoJuliet_res3500
# Measured galaxy 'm12_elvis_RomeoJuliet_res3500' at snapshot '041' in 321.73 seconds
# Coordinates saved to m12 redshift shapes/romeo_02/romeo_coords_041.csv
# measured galaxy m12_elvis_RomeoJuliet_res3500
# Measured galaxy 'm12_elvis_RomeoJuliet_res3500' at snapshot '059' in 326.61 seconds
# Coordinates saved to m12 redshift shapes/romeo_02/romeo_coords_059.csv
# measured galaxy m12_elvis_RomeoJuliet_res3500
# ...
