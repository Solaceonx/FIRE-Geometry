# %% [raw]
# import plot_galaxy as gplot
# import mg2

# %%
sim_inputs = ['m11c_res2100']
snap_num_input = 600
for i in range(5):
    j = 6-i
    output_file = 'm11c_pf' + str(j) + '.csv'
    pf = [0.000277777777777*j]
    results = mg2.find_galaxy_shape3(sim_inputs, output_file, snap_num_input, particle_fractions = pf, repeats = 100)
# Out:
# Loading halo took 0.11 seconds
# Loading simulation data and masking to halo took 44.55 seconds
# Iteration 1 took 0.05 seconds (Cumulative: 0.05 seconds)
# Iteration 2 took 0.05 seconds (Cumulative: 0.10 seconds)
# Iteration 3 took 0.05 seconds (Cumulative: 0.14 seconds)
# Iteration 4 took 0.05 seconds (Cumulative: 0.19 seconds)
# Iteration 5 took 0.05 seconds (Cumulative: 0.24 seconds)
# Iteration 6 took 0.05 seconds (Cumulative: 0.29 seconds)
# Iteration 7 took 0.05 seconds (Cumulative: 0.35 seconds)
# Iteration 8 took 0.05 seconds (Cumulative: 0.39 seconds)
# Iteration 9 took 0.05 seconds (Cumulative: 0.44 seconds)
# Iteration 1 took 0.05 seconds (Cumulative: 0.05 seconds)
# Iteration 2 took 0.05 seconds (Cumulative: 0.10 seconds)
# Iteration 3 took 0.05 seconds (Cumulative: 0.15 seconds)
# Iteration 4 took 0.05 seconds (Cumulative: 0.20 seconds)
# Iteration 5 took 0.05 seconds (Cumulative: 0.24 seconds)
# Iteration 6 took 0.05 seconds (Cumulative: 0.29 seconds)
# ...

# %%
sim_inputs = ['m11c_res2100']
snap_num_input = 600
for i in range(1):
    j = 10-i-1
    output_file = 'm11c_pf' + str(j) + '.csv'
    pf = [0.1*j]
    results = mg2.find_galaxy_shape3(sim_inputs, output_file, snap_num_input, particle_fractions = pf, repeats = 100)
# Out:
# Loading halo took 0.06 seconds
# Loading simulation data and masking to halo took 47.14 seconds
# Iteration 1 took 26.83 seconds (Cumulative: 26.83 seconds)
# Iteration 2 took 24.88 seconds (Cumulative: 51.71 seconds)
# Iteration 3 took 26.45 seconds (Cumulative: 78.16 seconds)
# Iteration 4 took 25.82 seconds (Cumulative: 103.98 seconds)
# Iteration 5 took 25.75 seconds (Cumulative: 129.73 seconds)
# Iteration 6 took 26.43 seconds (Cumulative: 156.16 seconds)
# Iteration 7 took 25.64 seconds (Cumulative: 181.80 seconds)
# Iteration 8 took 25.95 seconds (Cumulative: 207.75 seconds)
# Iteration 1 took 26.47 seconds (Cumulative: 26.47 seconds)
# Iteration 2 took 24.61 seconds (Cumulative: 51.08 seconds)
# Iteration 3 took 24.55 seconds (Cumulative: 75.63 seconds)
# Iteration 4 took 24.66 seconds (Cumulative: 100.29 seconds)
# Iteration 5 took 24.48 seconds (Cumulative: 124.78 seconds)
# Iteration 6 took 24.45 seconds (Cumulative: 149.22 seconds)
# ...

# %%
sim_inputs = ['m10d_res500']
# m11c, m10d
snap_num_input = 184

for i in range(9):
    j = 10-i-1
    output_file = 'm10d_pf' + str(j) + '.csv'
    pf = [0.1*j]
    results = mg2.find_galaxy_shape3(sim_inputs, output_file, snap_num_input, particle_fractions = pf, repeats = 100)

for i in range(4):
    j = 2*(5 - i - 1) # 8, 4, 6, 2
    pf = [0.01*j]
    output_file = 'm10d_pf0' + str(j) + '.csv'
    results = mg2.find_galaxy_shape3(sim_inputs, output_file, snap_num_input, particle_fractions = pf, repeats = 100)

# %%
sim_inputs = ['m10i_res500']
snap_num_input = 184
for i in range(9):
    j = 10-i-1
    output_file = 'm10i_pf' + str(j) + '.csv'
    pf = [0.1*j]
    results = mg2.find_galaxy_shape3(sim_inputs, output_file, snap_num_input, particle_fractions = pf, repeats = 100)

for i in range(4):
    j = 2*(5 - i - 1) # 8, 4, 6, 2
    pf = [0.01*j]
    output_file = 'm10i_pf0' + str(j) + '.csv'
    results = mg2.find_galaxy_shape3(sim_inputs, output_file, snap_num_input, particle_fractions = pf, repeats = 100)
