# %%
import plot_galaxy as gplot
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Usage example:
csv_files = [
    '3D shapes/test.csv'
]

gplot.baca(csv_files)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       1 # Usage example:
#       2 csv_files = [
#       3     '3D shapes/test.csv'
#       4 ]
# ----> 6 gplot.baca(csv_files)
#
# NameError: name 'gplot' is not defined

# %%
csv_files = [
    '3D shapes/FIREm11.csv'
]
gplot.baloga_3d(csv_files)

# %%
csv_files = [
    '2D shapes/object_398.csv'
]
gplot.baloga_2d(csv_files)
