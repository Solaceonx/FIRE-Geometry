# %%
import plot_galaxy as gplot
import mg
import os
import time
import matplotlib.pyplot as plt
import galaxy_tools
# %matplotlib inline
# sim_inputs = ['object_965']
sim_inputs = ['object_284', 'object_321', 'object_378']
# sim_inputs = ['object_22', 'object_74', 'object_52', 'object_19', 'object_51', 'object_35', 'object_28', 'object_24', 'object_103', 'object_57', 'object_54', 'object_67', 'object_69', 'object_70', 'object_58', 'object_21', 'object_11', 'object_59', 'object_68', 'object_62', 'object_76', 'object_27', 'object_30']
path = '/DFS-L/DATA/cosmo/jgmoren1/FIREBox/FB15N1024/objects_1200/' # /object_398.hdf5'

# visual inspection of cms and initial max radii of the outlier galaxies:
# 284: 3 galaxies, ([0 -5 0], 25), ([-30, 20 -30], 15), ([-25 -50 75], 15)
# 321: 1 main galaxy + satellite, ([0 0 0], 40), ([20 75 70], 25)
# 378: 2 galaxies, ([-5 0 0], 25), ([-5 45 0], 20)
# Out:
# Missing firefly, obtain it at http://github.com/ageller/Firefly or pip install firefly.

# %%
sim_input = ['object_284']
output_file = 'object_284_1.csv'
results = mg.outlier_shape3d(sim_input, output_file, cutoff_radius = 40, cm = [0, -5, 0], FIREBox=1)
galaxy = results[0]['remaining_galaxy']
x, p, q = results[0]['max_radius'], results[0]['b/a'], results[0]['c/a']
y, z = x*p, x*q
gplot.scatter_ellipsoid_3d(galaxy, axis_lengths=(x, y, z))

output_file = 'object_284_2.csv'
results = mg.outlier_shape3d(sim_input, output_file, cutoff_radius = 25, cm = [-38, 22, -30], FIREBox=1)
galaxy = results[0]['remaining_galaxy']
x, p, q = results[0]['max_radius'], results[0]['b/a'], results[0]['c/a']
y, z = x*p, x*q
gplot.scatter_ellipsoid_3d(galaxy, axis_lengths=(x, y, z))


output_file = 'object_284_3.csv'
results = mg.outlier_shape3d(sim_input, output_file, cutoff_radius = 15, cm = [-25, -50, 75], FIREBox=1)
galaxy = results[0]['remaining_galaxy']
x, p, q = results[0]['max_radius'], results[0]['b/a'], results[0]['c/a']
y, z = x*p, x*q
gplot.scatter_ellipsoid_3d(galaxy, axis_lengths=(x, y, z))
# Out:
# measured object_284_1
# measured object_284_2
# measured object_284_3

# %%
sim_input = ['object_321']
output_file = 'object_321_1.csv'
results = mg.outlier_shape3d(sim_input, output_file, cutoff_radius = 25, cm = [0, 0, 0], FIREBox=1)
galaxy = results[0]['remaining_galaxy']
x, p, q = results[0]['max_radius'], results[0]['b/a'], results[0]['c/a']
y, z = x*p, x*q
gplot.scatter_ellipsoid_3d(galaxy, axis_lengths=(x, y, z))


output_file = 'object_321_2.csv'
results = mg.outlier_shape3d(sim_input, output_file, cutoff_radius = 20, cm = [20, 85, 70], FIREBox=1)
galaxy = results[0]['remaining_galaxy']
x, p, q = results[0]['max_radius'], results[0]['b/a'], results[0]['c/a']
y, z = x*p, x*q
gplot.scatter_ellipsoid_3d(galaxy, axis_lengths=(x, y, z))
# Out:
# measured object_321_1
# measured object_321_2

# %%
# 104: 2 galaxies, ([0 0 0], 40), ([35, -110, -50], 50)
# 239: 2 galaxies, ([0 0 0], 50), ([35, -110, 25], 40)
sim_input = ['object_104']
output_file = 'object_104_1.csv'
results = mg.outlier_shape3d(sim_input, output_file, cutoff_radius = 50, cm = [0, 0, 0], FIREBox=1)
galaxy = results[0]['remaining_galaxy']
x, p, q = results[0]['max_radius'], results[0]['b/a'], results[0]['c/a']
y, z = x*p, x*q
gplot.scatter_ellipsoid_3d(galaxy, axis_lengths=(x, y, z))

output_file = 'object_104_2.csv'
results = mg.outlier_shape3d(sim_input, output_file, cutoff_radius = 25, cm = [35, -110, -50], FIREBox=1)
galaxy = results[0]['remaining_galaxy']
x, p, q = results[0]['max_radius'], results[0]['b/a'], results[0]['c/a']
y, z = x*p, x*q
gplot.scatter_ellipsoid_3d(galaxy, axis_lengths=(x, y, z))
# Out:
# measured object_104_1
# measured object_104_2

# %%
sim_input = ['object_239']
output_file = 'object_239_1.csv'
results = mg.outlier_shape3d(sim_input, output_file, cutoff_radius = 50, cm = [0, 0, 0], FIREBox=1)
galaxy = results[0]['remaining_galaxy']
x, p, q = results[0]['max_radius'], results[0]['b/a'], results[0]['c/a']
y, z = x*p, x*q
gplot.scatter_ellipsoid_3d(galaxy, axis_lengths=(x, y, z))

output_file = 'object_239_2.csv'
results = mg.outlier_shape3d(sim_input, output_file, cutoff_radius = 50, cm = [-80, -50, 25], FIREBox=1)
galaxy = results[0]['remaining_galaxy']
x, p, q = results[0]['max_radius'], results[0]['b/a'], results[0]['c/a']
y, z = x*p, x*q
gplot.scatter_ellipsoid_3d(galaxy, axis_lengths=(x, y, z))
# Out:
# measured object_239_1
# measured object_239_2

# %%
# 143: 2 galaxies, ([0 0 0], 40), ([10 85 -50], 30)
# 90: 2 galaxies, ([0 0 0], 45), ([10, -90, 45], 30)
# 141: 2 galaxies VERY close together, might be hard to measure
# , ([0 0 0], 25), ([35, -30, -35], 30)

sim_input = ['object_143']
output_file = 'object_143_1.csv'
results = mg.outlier_shape3d(sim_input, output_file, cutoff_radius = 40, cm = [0, 0, 0], FIREBox=1)
galaxy = results[0]['remaining_galaxy']
x, p, q = results[0]['max_radius'], results[0]['b/a'], results[0]['c/a']
y, z = x*p, x*q
gplot.scatter_ellipsoid_3d(galaxy, axis_lengths=(x, y, z))

output_file = 'object_143_2.csv'
results = mg.outlier_shape3d(sim_input, output_file, cutoff_radius = 30, cm = [10, 85, -50], FIREBox=1)
galaxy = results[0]['remaining_galaxy']
x, p, q = results[0]['max_radius'], results[0]['b/a'], results[0]['c/a']
y, z = x*p, x*q
gplot.scatter_ellipsoid_3d(galaxy, axis_lengths=(x, y, z))
# Out:
# measured object_143_1
# measured object_143_2

# %%
sim_input = ['object_90']
output_file = 'object_90_1.csv'
results = mg.outlier_shape3d(sim_input, output_file, cutoff_radius = 40, cm = [0, 0, 0], FIREBox=1)
galaxy = results[0]['remaining_galaxy']
x, p, q = results[0]['max_radius'], results[0]['b/a'], results[0]['c/a']
y, z = x*p, x*q
gplot.scatter_ellipsoid_3d(galaxy, axis_lengths=(x, y, z))

output_file = 'object_90_2.csv'
results = mg.outlier_shape3d(sim_input, output_file, cutoff_radius = 30, cm = [25, -90, 35], FIREBox=1)
galaxy = results[0]['remaining_galaxy']
x, p, q = results[0]['max_radius'], results[0]['b/a'], results[0]['c/a']
y, z = x*p, x*q
gplot.scatter_ellipsoid_3d(galaxy, axis_lengths=(x, y, z))
# Out:
# measured object_90_1
# measured object_90_2

# %%
# 60 -120 -130
sim_input = ['object_51']
output_file = 'object_51_1.csv'
results = mg.outlier_shape3d(sim_input, output_file, cutoff_radius = 55, cm = [0, 0, 0], FIREBox=1)
galaxy = results[0]['remaining_galaxy']
x, p, q = results[0]['max_radius'], results[0]['b/a'], results[0]['c/a']
y, z = x*p, x*q
gplot.scatter_ellipsoid_3d(galaxy, axis_lengths=(x, y, z))

output_file = 'object_51_2.csv'
results = mg.outlier_shape3d(sim_input, output_file, cutoff_radius = 55, cm = [60, -120, -130], FIREBox=1)
galaxy = results[0]['remaining_galaxy']
x, p, q = results[0]['max_radius'], results[0]['b/a'], results[0]['c/a']
y, z = x*p, x*q
gplot.scatter_ellipsoid_3d(galaxy, axis_lengths=(x, y, z))
# Out:
# measured object_51_1
# measured object_51_2

# %%
import os
import pandas as pd

# Specify the folder containing the CSV files
folder_path = 'outlier shapes'

# Initialize an empty list to hold the DataFrames
df_list = []

# Loop over all the files in the folder
for filename in os.listdir(folder_path):
    if filename.endswith('.csv'):
        file_path = os.path.join(folder_path, filename)
        # Read the CSV file into a DataFrame
        df = pd.read_csv(file_path)
        # Append the DataFrame to the list
        df_list.append(df)

# Concatenate all the DataFrames in the list into a single DataFrame
combined_df = pd.concat(df_list, ignore_index=True)

# Specify the output file path
output_file_path = 'outlier shapes/combined_file.csv'

# Save the combined DataFrame to a new CSV file
combined_df.to_csv(output_file_path, index=False)

print(f"All CSV files have been combined and saved to {output_file_path}")
# Out:
# CSV files found: ['object_239_1.csv', 'object_321_1.csv', 'object_143_2.csv', 'object_51_2.csv', 'object_284_1.csv', 'object_90_1.csv', 'object_104_1.csv', 'outliers.csv', 'object_104_2.csv', 'object_398.csv', 'outliers_combined.csv', 'object_51_1.csv', 'object_284_2.csv', 'object_90_2.csv', 'object_321_2.csv', 'object_143_1.csv', 'object_284_3.csv', 'object_239_2.csv']
# Columns in the first file: Index(['Simulation', 'a', 'b', 'c', 'b/a', 'c/a', 'c/b', 'ellipticity',
#        'triaxiality', 'Iterations', 'Initial Particles', 'Remaining Particles',
#        'Max Radius', 'r_50', 'mass', 'Center of Mass', 'Rotation Matrix'],
#       dtype='object')
# Combined CSV file saved successfully to outlier shapes/outliers_combined.csv
