# %%
# outlier galaxies
# I identified these by selecting galaxies that seemed unusually large when I first measured them.
# m7: 965
# m8: 284, 321, 378
# m9: 90, 104, 239, 143, 141
# m10: 22, 74, 52, 19, 51, 35, 28, 24, 103, 57, 54, 67, 69, 70, 58, 21, 11, 59, 68, 62, 76, 27, 30
import plot_galaxy as gplot
import mg
import os
import time
import matplotlib.pyplot as plt
import galaxy_tools
# %matplotlib inline
# sim_inputs = ['object_965']
sim_inputs = ['object_284', 'object_321', 'object_378']
# sim_inputs = ['object_22', 'object_74', 'object_52', 'object_19', 'object_51', 'object_35', 'object_28', 'object_24', 'object_103', 'object_57', 'object_54', 'object_67', 'object_69', 'object_70', 'object_58', 'object_21', 'object_11', 'object_59', 'object_68', 'object_62', 'object_76', 'object_27', 'object_30']
path = '/DFS-L/DATA/cosmo/jgmoren1/FIREBox/FB15N1024/objects_1200/' # /object_398.hdf5'
'''
for sim_input in sim_inputs:
    # output_file = f'{sim_input}.csv'  # Create output filename
    sim_path = path + str(sim_input) + '.hdf5'
    star_snapdict, gas_snapdict = galaxy_tools.load_sim_FIREBox(sim_path) 
    # results = mg.find_galaxy_shape3d(sim_input, output_file, FIREBox=1)
    gplot.scatter_3d(star_snapdict)
    gplot.scatter_2d(star_snapdict, projection = 'xy')
    gplot.scatter_2d(star_snapdict, projection = 'yz')
    gplot.scatter_2d(star_snapdict, projection = 'zx')
'''
# visual inspection of cms and initial max radii of the outlier galaxies:
# 284: 3 galaxies, ([0 -5 0], 15), ([-30, 20 -30], 15), ([-25 -50 75], 15)
# 321: 1 main galaxy + satellite, ([0 0 0], 40), ([20 75 70], 25)
# 378: 2 galaxies, ([-5 0 0], 25), ([-5 45 0], 20)
# Out:
# Missing firefly, obtain it at http://github.com/ageller/Firefly or pip install firefly.
# "\nfor sim_input in sim_inputs:\n    # output_file = f'{sim_input}.csv'  # Create output filename\n    sim_path = path + str(sim_input) + '.hdf5'\n    star_snapdict, gas_snapdict = galaxy_tools.load_sim_FIREBox(sim_path) \n    # results = mg.find_galaxy_shape3d(sim_input, output_file, FIREBox=1)\n    gplot.scatter_3d(star_snapdict)\n    gplot.scatter_2d(star_snapdict, projection = 'xy')\n    gplot.scatter_2d(star_snapdict, projection = 'yz')\n    gplot.scatter_2d(star_snapdict, projection = 'zx')\n"

# %%
sim_inputs = ['object_104', 'object_239']
for sim_input in sim_inputs:
    # output_file = f'{sim_input}.csv'  # Create output filename
    sim_path = path + str(sim_input) + '.hdf5'
    star_snapdict, gas_snapdict = galaxy_tools.load_sim_FIREBox(sim_path) 
    # results = mg.find_galaxy_shape3d(sim_input, output_file, FIREBox=1)
    gplot.scatter_3d(star_snapdict)
    gplot.scatter_2d(star_snapdict, projection = 'xy')
    gplot.scatter_2d(star_snapdict, projection = 'yz')
    gplot.scatter_2d(star_snapdict, projection = 'zx')
# 104: 2 galaxies, ([0 0 0], 40), ([35, -50, -10], 50)
# 239: 2 galaxies, ([0 0 0], 50), ([35, -110, 25], 40)

# %%
sim_inputs = ['object_143', 'object_90', 'object_141']
for sim_input in sim_inputs:
    # output_file = f'{sim_input}.csv'  # Create output filename
    sim_path = path + str(sim_input) + '.hdf5'
    star_snapdict, gas_snapdict = galaxy_tools.load_sim_FIREBox(sim_path) 
    # results = mg.find_galaxy_shape3d(sim_input, output_file, FIREBox=1)
    gplot.scatter_3d(star_snapdict)
    gplot.scatter_2d(star_snapdict, projection = 'xy')
    gplot.scatter_2d(star_snapdict, projection = 'yz')
    gplot.scatter_2d(star_snapdict, projection = 'zx')
# 143: 2 galaxies, ([0 0 0], 40), ([10 85 -50], 30)
# 90: 2 galaxies, ([0 0 0], 45), ([10, -90, 45], 30)
# 141: 2 galaxies VERY close together, might be hard to measure
# , ([0 0 0], 25), ([35, -30, -35], 30)

# %%
sim_inputs = ['object_22', 'object_74', 'object_52']
for sim_input in sim_inputs:
    # output_file = f'{sim_input}.csv'  # Create output filename
    sim_path = path + str(sim_input) + '.hdf5'
    star_snapdict, gas_snapdict = galaxy_tools.load_sim_FIREBox(sim_path) 
    # results = mg.find_galaxy_shape3d(sim_input, output_file, FIREBox=1)
    gplot.scatter_3d(star_snapdict)
    gplot.scatter_2d(star_snapdict, projection = 'xy')
    gplot.scatter_2d(star_snapdict, projection = 'yz')
    gplot.scatter_2d(star_snapdict, projection = 'zx')

# %%
sim_inputs = ['object_19', 'object_51', 'object_35']
for sim_input in sim_inputs:
    # output_file = f'{sim_input}.csv'  # Create output filename
    sim_path = path + str(sim_input) + '.hdf5'
    star_snapdict, gas_snapdict = galaxy_tools.load_sim_FIREBox(sim_path) 
    # results = mg.find_galaxy_shape3d(sim_input, output_file, FIREBox=1)
    gplot.scatter_3d(star_snapdict)
    gplot.scatter_2d(star_snapdict, projection = 'xy')
    gplot.scatter_2d(star_snapdict, projection = 'yz')
    gplot.scatter_2d(star_snapdict, projection = 'zx')

# %%
sim_inputs = ['object_28', 'object_24', 'object_103']
for sim_input in sim_inputs:
    # output_file = f'{sim_input}.csv'  # Create output filename
    sim_path = path + str(sim_input) + '.hdf5'
    star_snapdict, gas_snapdict = galaxy_tools.load_sim_FIREBox(sim_path) 
    # results = mg.find_galaxy_shape3d(sim_input, output_file, FIREBox=1)
    gplot.scatter_3d(star_snapdict)
    gplot.scatter_2d(star_snapdict, projection = 'xy')
    gplot.scatter_2d(star_snapdict, projection = 'yz')
    gplot.scatter_2d(star_snapdict, projection = 'zx')

# %%
sim_inputs = ['object_57', 'object_54', 'object_67']
for sim_input in sim_inputs:
    # output_file = f'{sim_input}.csv'  # Create output filename
    sim_path = path + str(sim_input) + '.hdf5'
    star_snapdict, gas_snapdict = galaxy_tools.load_sim_FIREBox(sim_path) 
    # results = mg.find_galaxy_shape3d(sim_input, output_file, FIREBox=1)
    gplot.scatter_3d(star_snapdict)
    gplot.scatter_2d(star_snapdict, projection = 'xy')
    gplot.scatter_2d(star_snapdict, projection = 'yz')
    gplot.scatter_2d(star_snapdict, projection = 'zx')

# %%
sim_inputs = ['object_69', 'object_70', 'object_58']
for sim_input in sim_inputs:
    # output_file = f'{sim_input}.csv'  # Create output filename
    sim_path = path + str(sim_input) + '.hdf5'
    star_snapdict, gas_snapdict = galaxy_tools.load_sim_FIREBox(sim_path) 
    # results = mg.find_galaxy_shape3d(sim_input, output_file, FIREBox=1)
    gplot.scatter_3d(star_snapdict)
    gplot.scatter_2d(star_snapdict, projection = 'xy')
    gplot.scatter_2d(star_snapdict, projection = 'yz')
    gplot.scatter_2d(star_snapdict, projection = 'zx')

# %%
sim_inputs = ['object_21', 'object_11', 'object_59']
for sim_input in sim_inputs:
    # output_file = f'{sim_input}.csv'  # Create output filename
    sim_path = path + str(sim_input) + '.hdf5'
    star_snapdict, gas_snapdict = galaxy_tools.load_sim_FIREBox(sim_path) 
    # results = mg.find_galaxy_shape3d(sim_input, output_file, FIREBox=1)
    gplot.scatter_3d(star_snapdict)
    gplot.scatter_2d(star_snapdict, projection = 'xy')
    gplot.scatter_2d(star_snapdict, projection = 'yz')
    gplot.scatter_2d(star_snapdict, projection = 'zx')

# %%
sim_inputs = ['object_68', 'object_62', 'object_76']
for sim_input in sim_inputs:
    # output_file = f'{sim_input}.csv'  # Create output filename
    sim_path = path + str(sim_input) + '.hdf5'
    star_snapdict, gas_snapdict = galaxy_tools.load_sim_FIREBox(sim_path) 
    # results = mg.find_galaxy_shape3d(sim_input, output_file, FIREBox=1)
    gplot.scatter_3d(star_snapdict)
    gplot.scatter_2d(star_snapdict, projection = 'xy')
    gplot.scatter_2d(star_snapdict, projection = 'yz')
    gplot.scatter_2d(star_snapdict, projection = 'zx')

# %%
sim_inputs = ['object_27', 'object_30']
for sim_input in sim_inputs:
    # output_file = f'{sim_input}.csv'  # Create output filename
    sim_path = path + str(sim_input) + '.hdf5'
    star_snapdict, gas_snapdict = galaxy_tools.load_sim_FIREBox(sim_path) 
    # results = mg.find_galaxy_shape3d(sim_input, output_file, FIREBox=1)
    gplot.scatter_3d(star_snapdict)
    gplot.scatter_2d(star_snapdict, projection = 'xy')
    gplot.scatter_2d(star_snapdict, projection = 'yz')
    gplot.scatter_2d(star_snapdict, projection = 'zx')

# %%
# List of numbers
# numbers = [22, 74, 52, 19, 51, 35, 28, 24, 103, 57, 54, 67, 69, 70, 58, 21, 11, 59, 68, 62, 76, 27, 30]
numbers = [284, 321, 378]
numbers = [104, 239, 143, 99, 141]
# Convert to list of strings in the form 'object_<number>'
object_list = [f'object_{num}' for num in numbers]

# Print the resulting list
print(object_list)

# %%
sim_inputs = ['object_22', 'object_74', 'object_52', 'object_19', 'object_51', 'object_35', 'object_28', 'object_24', 'object_103', 'object_57', 'object_54', 'object_67', 'object_69', 'object_70', 'object_58', 'object_21', 'object_11', 'object_59', 'object_68', 'object_62', 'object_76', 'object_27', 'object_30']
